# %% [markdown]
# ![image.png](attachment:085ea843-1282-4888-b34b-1a02abfb1bcf.png)

# %% [markdown]
# ![image.png](attachment:7dbb4010-08cd-4d76-a611-c0a1e7782de6.png)

# %%
# !pip install psycopg2-binary
# Out:
# Requirement already satisfied: psycopg2-binary in /opt/conda/lib/python3.9/site-packages (2.8.6)

# %% [markdown]
# ## The following is the list of the connection parameters:
#
# - database: the name of the database that you want to connect.
# - user: the username used to authenticate.
# - password: password used to authenticate.
# - host: database server address e.g., localhost or an IP address.
# - port: the port number that defaults to 5432 if it is not provided

# %%
try:
    from faker import Faker
except:
   # !pip install faker 
   from faker import Faker
    
try:
    import psycopg2 
except:
    # !pip install psycopg2-binary 
    import psycopg2
    
try:
    from sqlalchemy import create_engine
except:
    # !pip install sqlalchemy
    from sqlalchemy import create_engine
    
    
try:
    import pandas as pd 
except:
    # !pip install pandas
    import pandas as pd
# Out:
# Collecting pandas
#   Downloading pandas-1.2.4-cp39-cp39-manylinux1_x86_64.whl (9.7 MB)
#      |████████████████████████████████| 9.7 MB 8.9 MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.9/site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/lib/python3.9/site-packages (from pandas) (1.20.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.9/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Installing collected packages: pandas
# Successfully installed pandas-1.2.4

# %%
from sqlalchemy import create_engine
import psycopg2

host="postgres"
database="testDB"
user="me"
password="1234"
port='5432'
engine = create_engine(f'postgresql://{user}:{password}@{host}:{port}/{database}')
print(engine.table_names())
# Out:
# ['table1', 'user', 'user_prefs', 'users2020', 'users20202', 'users202022']
# <ipython-input-135-84e53b4439b2>:10: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   print(engine.table_names())

# %% [markdown]
# ## Create DataFrame from faker

# %%
from faker import Faker
import csv
import pandas as pd 
output=open('data.csv','w')
fake=Faker()
header=['name','age','street','city','state','zip','lng','lat']
mywriter=csv.writer(output)
mywriter.writerow(header)
for r in range(1000):
    row =[fake.name(),fake.random_int(min=18,max=80, step=1), 
                       fake.street_address(), fake.city(),fake.state(),
                       fake.zipcode(),fake.longitude(),fake.latitude()]
    mywriter.writerow(row)

output.close()

DF=pd.read_csv('data.csv')

DF.head(10)
# Out:
#                 name  age                          street  \
# 0  Christopher Kirby   55                109 Johnson Fort
# 1       Kim Copeland   74               5666 Meza Terrace
# 2       Rachel Burns   44        6205 Lewis Ways Apt. 948
# 3      Debra Johnson   32      946 Jeffrey Parks Apt. 269
# 4    Steven Browning   21              481 Baxter Station
# 5      Timothy Ramos   39        2343 Larry Mall Apt. 223
# 6   Crystal Anderson   79  214 Robertson Heights Apt. 800
# 7      Edward Morris   62      5457 Cuevas Manor Apt. 435
# 8       Chris French   37                 0530 Lisa Union
# 9   Michael Gonzales   39                  441 Rocha Mall
#
#                   city           state    zip         lng        lat
# 0             Choifort     Connecticut  57254 -164.561063 -43.109763
# 1     East Adamborough        Delaware  78598  -34.458157  61.568436
# 2         Richardhaven  North Carolina  53179 -108.769153 -19.705131
# 3           Lake Megan   Massachusetts  27074   81.858732 -16.605923
# 4           West Aaron           Texas  16203  118.709287  81.643360
# 5            West Todd            Utah  79444   87.219820 -52.743884
# 6         Timothymouth      New Jersey  39476   46.499576 -83.323573
# 7   North Michaelburgh         Georgia   6021   73.971332  13.871802
# 8  Lake Christopherton        Oklahoma  36107    1.806177  27.087322
# 9        Fernandeztown            Ohio  45893  -99.368545 -39.883759

# %% [markdown]
# ## Push the dataframe as table on PostGresql DB

# %%
DF.to_sql('users2020', engine,if_exists='replace',index=False)

# %% [markdown]
# ![image.png](attachment:65b93d2c-9f94-417b-b4c3-5ae70e6720dc.png)

# %% [markdown]
# ## Pull table from Postgresql DB

# %%
DF2=pd.read_sql("SELECT * FROM users2020" , engine);

# %%
DF2.head(10)
# Out:
#                 name  age                          street  \
# 0  Christopher Kirby   55                109 Johnson Fort
# 1       Kim Copeland   74               5666 Meza Terrace
# 2       Rachel Burns   44        6205 Lewis Ways Apt. 948
# 3      Debra Johnson   32      946 Jeffrey Parks Apt. 269
# 4    Steven Browning   21              481 Baxter Station
# 5      Timothy Ramos   39        2343 Larry Mall Apt. 223
# 6   Crystal Anderson   79  214 Robertson Heights Apt. 800
# 7      Edward Morris   62      5457 Cuevas Manor Apt. 435
# 8       Chris French   37                 0530 Lisa Union
# 9   Michael Gonzales   39                  441 Rocha Mall
#
#                   city           state    zip         lng        lat
# 0             Choifort     Connecticut  57254 -164.561063 -43.109763
# 1     East Adamborough        Delaware  78598  -34.458157  61.568436
# 2         Richardhaven  North Carolina  53179 -108.769153 -19.705131
# 3           Lake Megan   Massachusetts  27074   81.858732 -16.605923
# 4           West Aaron           Texas  16203  118.709287  81.643360
# 5            West Todd            Utah  79444   87.219820 -52.743884
# 6         Timothymouth      New Jersey  39476   46.499576 -83.323573
# 7   North Michaelburgh         Georgia   6021   73.971332  13.871802
# 8  Lake Christopherton        Oklahoma  36107    1.806177  27.087322
# 9        Fernandeztown            Ohio  45893  -99.368545 -39.883759

# %% [markdown]
# ##  Transforming the DF2 by adding new colum called sallary

# %%
import random 
DF2['salary']=DF2['age'].apply(lambda x:int(random.random()*10000) )

# %%
DF2.head(10)
# Out:
#                 name  age                          street  \
# 0  Christopher Kirby   55                109 Johnson Fort
# 1       Kim Copeland   74               5666 Meza Terrace
# 2       Rachel Burns   44        6205 Lewis Ways Apt. 948
# 3      Debra Johnson   32      946 Jeffrey Parks Apt. 269
# 4    Steven Browning   21              481 Baxter Station
# 5      Timothy Ramos   39        2343 Larry Mall Apt. 223
# 6   Crystal Anderson   79  214 Robertson Heights Apt. 800
# 7      Edward Morris   62      5457 Cuevas Manor Apt. 435
# 8       Chris French   37                 0530 Lisa Union
# 9   Michael Gonzales   39                  441 Rocha Mall
#
#                   city           state    zip         lng        lat  salary
# 0             Choifort     Connecticut  57254 -164.561063 -43.109763    3211
# 1     East Adamborough        Delaware  78598  -34.458157  61.568436    6096
# 2         Richardhaven  North Carolina  53179 -108.769153 -19.705131    1774
# 3           Lake Megan   Massachusetts  27074   81.858732 -16.605923    4199
# 4           West Aaron           Texas  16203  118.709287  81.643360    4205
# 5            West Todd            Utah  79444   87.219820 -52.743884    9458
# 6         Timothymouth      New Jersey  39476   46.499576 -83.323573    6927
# 7   North Michaelburgh         Georgia   6021   73.971332  13.871802    2210
# 8  Lake Christopherton        Oklahoma  36107    1.806177  27.087322    1003
# 9        Fernandeztown            Ohio  45893  -99.368545 -39.883759    2798

# %% [markdown]
# ##  Push the new DF2 as an updated table users2020

# %%
DF2.to_sql('users2020', engine,if_exists='replace',index=False)

# %% [markdown]
# ![image.png](attachment:3b5ebb3a-e4a7-483b-a89b-521d0f933530.png)

# %%
Count_records=pd.read_sql("SELECT COUNT(*) FROM users2020" , engine);
D
# Out:
#    count
# 0   1000

# %%
DF2.tail(10)
# Out:
#                      name  age                       street             city  \
# 990     Christian Bullock   48  0160 Brooks Mount Suite 971      Brookshaven
# 991  Christopher Anderson   49   148 Amber Circles Apt. 997    Michellehaven
# 992       Ralph Robertson   50    764 Ramos Plaza Suite 808     Lake Allison
# 993         Kenneth Henry   35             769 Hunter Spurs    Samuelchester
# 994       Gregory Hopkins   29             25334 Payne Mews        Dustinton
# 995         Thomas Howard   31   622 Corey Freeway Apt. 456      Charlesstad
# 996         Julia Daniels   71         76125 Angela Mission        Mooreview
# 997            Anna Davis   78        69732 Alexander Point  Christopherland
# 998     Ms. Taylor French   60  7089 Rebecca Plain Apt. 218       Boyermouth
# 999           Cathy Weber   31           57661 Erika Fields  East Ronaldbury
#
#               state    zip         lng        lat  salary
# 990   Massachusetts  77678 -164.809043  41.609034    8316
# 991       Louisiana  36247  130.328210 -55.774455    6462
# 992       Wisconsin  32121 -153.666427  69.111435    2721
# 993           Maine  26833  -82.591832  57.306566     362
# 994        Colorado  10401  -10.497127 -81.185143    8417
# 995        Arkansas  12426  100.119412  83.930187    1553
# 996        Oklahoma  10515 -143.853615 -50.543002    5221
# 997    South Dakota  65836  168.966645  86.506678    7829
# 998  North Carolina  21031  -10.832233 -85.001479    4869
# 999         Wyoming  81800   50.228057 -42.111039    6760

# %%
DF3=DF2.head(100)
DF3.index=range(len(DF2),len(DF2)+100)
DF3.head(3)
# Out:
#                    name  age                    street              city  \
# 1000  Christopher Kirby   55          109 Johnson Fort          Choifort
# 1001       Kim Copeland   74         5666 Meza Terrace  East Adamborough
# 1002       Rachel Burns   44  6205 Lewis Ways Apt. 948      Richardhaven
#
#                state    zip         lng        lat  salary
# 1000     Connecticut  57254 -164.561063 -43.109763    3211
# 1001        Delaware  78598  -34.458157  61.568436    6096
# 1002  North Carolina  53179 -108.769153 -19.705131    1774

# %% [markdown]
# ##  Append the new DF3 as an update to the table users2020

# %%
DF3.to_sql('users2020', engine,if_exists='append',index=False)

# %%
Count_records=pd.read_sql("SELECT COUNT(*) FROM users2020" , engine);
Count_records
# Out:
#    count
# 0   1100

# %%
DF4=pd.read_sql("SELECT * FROM users2020" , engine);

# %%
DF4.head(3)
# Out:
#                 name  age                    street              city  \
# 0  Christopher Kirby   55          109 Johnson Fort          Choifort
# 1       Kim Copeland   74         5666 Meza Terrace  East Adamborough
# 2       Rachel Burns   44  6205 Lewis Ways Apt. 948      Richardhaven
#
#             state    zip         lng        lat  salary
# 0     Connecticut  57254 -164.561063 -43.109763    3211
# 1        Delaware  78598  -34.458157  61.568436    6096
# 2  North Carolina  53179 -108.769153 -19.705131    1774

# %% [markdown]
# ## create, Insert, update, delete

# %%
from sqlalchemy import delete, insert, update

# %%
D=engine.execute('SELECT * FROM users2020 LIMIT 10;')

for row in D:
    print(row)
# Out:
# ('Christopher Kirby', 55, '109 Johnson Fort', 'Choifort', 'Connecticut', 57254, -164.561063, -43.109763, 3211)
# ('Kim Copeland', 74, '5666 Meza Terrace', 'East Adamborough', 'Delaware', 78598, -34.458157, 61.5684365, 6096)
# ('Rachel Burns', 44, '6205 Lewis Ways Apt. 948', 'Richardhaven', 'North Carolina', 53179, -108.769153, -19.705131, 1774)
# ('Debra Johnson', 32, '946 Jeffrey Parks Apt. 269', 'Lake Megan', 'Massachusetts', 27074, 81.858732, -16.605923, 4199)
# ('Steven Browning', 21, '481 Baxter Station', 'West Aaron', 'Texas', 16203, 118.709287, 81.6433595, 4205)
# ('Timothy Ramos', 39, '2343 Larry Mall Apt. 223', 'West Todd', 'Utah', 79444, 87.21982, -52.7438835, 9458)
# ('Crystal Anderson', 79, '214 Robertson Heights Apt. 800', 'Timothymouth', 'New Jersey', 39476, 46.499576, -83.323573, 6927)
# ('Edward Morris', 62, '5457 Cuevas Manor Apt. 435', 'North Michaelburgh', 'Georgia', 6021, 73.971332, 13.871802, 2210)
# ('Chris French', 37, '0530 Lisa Union', 'Lake Christopherton', 'Oklahoma', 36107, 1.806177, 27.087322, 1003)
# ('Michael Gonzales', 39, '441 Rocha Mall', 'Fernandeztown', 'Ohio', 45893, -99.368545, -39.883759, 2798)

# %%
Query='''INSERT INTO users2020 (name, age, street, city, state, zip, lng, lat,salary)
VALUES ('Christopher Kirby', 55, '109 Johnson Fort', 'Choifort', 'Connecticut', 57254, -164.561063, -43.109763, 3211);'''

engine.execute(Query)

# %%
Query='SELECT COUNT(*) FROM users2020;'
D=pd.read_sql(Query,engine)
D
# Out:
#    count
# 0   1101

# %%
D=engine.execute('SELECT COUNT(*) FROM users2020;')
list(D)[0][0]
# Out:
# 1101

# %%
D=engine.execute('SELECT * FROM users2020 LIMIT 10;')

for row in D:
    print(row)

Query='''
UPDATE users2020
SET name = 'Alfred Schmidt', city= 'Frankfurt'
WHERE name = 'Christopher Kirby';
'''

engine.execute(Query)
print('-----------------------------------------------------------------------------------------')
D=engine.execute('SELECT * FROM users2020 LIMIT 10;')

for row in D:
    print(row)
# Out:
# ('Kim Copeland', 74, '5666 Meza Terrace', 'East Adamborough', 'Delaware', 78598, -34.458157, 61.5684365, 6096)
# ('Rachel Burns', 44, '6205 Lewis Ways Apt. 948', 'Richardhaven', 'North Carolina', 53179, -108.769153, -19.705131, 1774)
# ('Debra Johnson', 32, '946 Jeffrey Parks Apt. 269', 'Lake Megan', 'Massachusetts', 27074, 81.858732, -16.605923, 4199)
# ('Steven Browning', 21, '481 Baxter Station', 'West Aaron', 'Texas', 16203, 118.709287, 81.6433595, 4205)
# ('Timothy Ramos', 39, '2343 Larry Mall Apt. 223', 'West Todd', 'Utah', 79444, 87.21982, -52.7438835, 9458)
# ('Crystal Anderson', 79, '214 Robertson Heights Apt. 800', 'Timothymouth', 'New Jersey', 39476, 46.499576, -83.323573, 6927)
# ('Edward Morris', 62, '5457 Cuevas Manor Apt. 435', 'North Michaelburgh', 'Georgia', 6021, 73.971332, 13.871802, 2210)
# ('Chris French', 37, '0530 Lisa Union', 'Lake Christopherton', 'Oklahoma', 36107, 1.806177, 27.087322, 1003)
# ('Michael Gonzales', 39, '441 Rocha Mall', 'Fernandeztown', 'Ohio', 45893, -99.368545, -39.883759, 2798)
# ('Jeffrey Macias', 49, '5035 Carlos Mall Suite 546', 'Grossport', 'Minnesota', 67985, 114.039627, -49.198333, 8204)
# ----------------------------------------------------
# ('Kim Copeland', 74, '5666 Meza Terrace', 'East Adamborough', 'Delaware', 78598, -34.458157, 61.5684365, 6096)
# ('Rachel Burns', 44, '6205 Lewis Ways Apt. 948', 'Richardhaven', 'North Carolina', 53179, -108.769153, -19.705131, 1774)
# ('Debra Johnson', 32, '946 Jeffrey Parks Apt. 269', 'Lake Megan', 'Massachusetts', 27074, 81.858732, -16.605923, 4199)
# ('Steven Browning', 21, '481 Baxter Station', 'West Aaron', 'Texas', 16203, 118.709287, 81.6433595, 4205)
# ('Timothy Ramos', 39, '2343 Larry Mall Apt. 223', 'West Todd', 'Utah', 79444, 87.21982, -52.7438835, 9458)
# ('Crystal Anderson', 79, '214 Robertson Heights Apt. 800', 'Timothymouth', 'New Jersey', 39476, 46.499576, -83.323573, 6927)
# ('Edward Morris', 62, '5457 Cuevas Manor Apt. 435', 'North Michaelburgh', 'Georgia', 6021, 73.971332, 13.871802, 2210)
# ('Chris French', 37, '0530 Lisa Union', 'Lake Christopherton', 'Oklahoma', 36107, 1.806177, 27.087322, 1003)
# ('Michael Gonzales', 39, '441 Rocha Mall', 'Fernandeztown', 'Ohio', 45893, -99.368545, -39.883759, 2798)
# ('Jeffrey Macias', 49, '5035 Carlos Mall Suite 546', 'Grossport', 'Minnesota', 67985, 114.039627, -49.198333, 8204)

# %%
DF5=pd.read_sql("SELECT * FROM users2020" , engine);
DF5.tail(10)
# Out:
#                     name  age                           street  \
# 1091  Mr. Jonathan Smith   67                 92454 Davis Dale
# 1092        Denise Glass   72         524 Miller Pike Apt. 303
# 1093     Ashley Chandler   64                293 Russell Cliff
# 1094     Alison Thompson   44   26064 Williams Glens Suite 661
# 1095        Rebecca Wood   26        879 Malone Burg Suite 416
# 1096        Sharon Wolfe   21  16339 Griffin Circles Suite 538
# 1097        Eric Barrett   79              52014 Mallory Mount
# 1098      Alfred Schmidt   55                 109 Johnson Fort
# 1099      Alfred Schmidt   55                 109 Johnson Fort
# 1100      Alfred Schmidt   55                 109 Johnson Fort
#
#                 city           state    zip         lng        lat  salary
# 1091       Ewingtown        Michigan  88361   69.068597 -12.158374    9377
# 1092       Hayesberg           Texas    916  -66.874498 -58.924698    6776
# 1093       Johnshire        Kentucky  79824  138.850295  24.234530    1122
# 1094  Lake Elizabeth  North Carolina  28899    8.872990 -68.956530    8251
# 1095       Barryland       Louisiana  25333 -119.649422 -14.125089    9297
# 1096   East Lawrence   New Hampshire  79067   51.374019  87.815861    4216
# 1097     Stewartberg      Washington  12542  -33.932771  66.293738    7007
# 1098       Frankfurt     Connecticut  57254 -164.561063 -43.109763    3211
# 1099       Frankfurt     Connecticut  57254 -164.561063 -43.109763    3211
# 1100       Frankfurt     Connecticut  57254 -164.561063 -43.109763    3211

# %%
Query='''
DELETE FROM users2020
WHERE name = 'Alfred Schmidt';
'''

engine.execute(Query)

DF5=pd.read_sql("SELECT * FROM users2020" , engine);
DF5.tail(10)
# Out:
#                     name  age                           street  \
# 1088      Steven Compton   53      50179 James Unions Apt. 366
# 1089      Melissa Haynes   41    848 Turner Motorway Suite 105
# 1090        Charles Hess   35                    206 Lisa Camp
# 1091  Mr. Jonathan Smith   67                 92454 Davis Dale
# 1092        Denise Glass   72         524 Miller Pike Apt. 303
# 1093     Ashley Chandler   64                293 Russell Cliff
# 1094     Alison Thompson   44   26064 Williams Glens Suite 661
# 1095        Rebecca Wood   26        879 Malone Burg Suite 416
# 1096        Sharon Wolfe   21  16339 Griffin Circles Suite 538
# 1097        Eric Barrett   79              52014 Mallory Mount
#
#                    city           state    zip         lng        lat  salary
# 1088       Martinezview        Kentucky  53805 -155.395441 -33.297750    8863
# 1089  Lake Benjaminland         Indiana  42454  -79.084484 -81.980482    9737
# 1090       Deborahmouth           Maine  26423  158.409507 -42.476630    7318
# 1091          Ewingtown        Michigan  88361   69.068597 -12.158374    9377
# 1092          Hayesberg           Texas    916  -66.874498 -58.924698    6776
# 1093          Johnshire        Kentucky  79824  138.850295  24.234530    1122
# 1094     Lake Elizabeth  North Carolina  28899    8.872990 -68.956530    8251
# 1095          Barryland       Louisiana  25333 -119.649422 -14.125089    9297
# 1096      East Lawrence   New Hampshire  79067   51.374019  87.815861    4216
# 1097        Stewartberg      Washington  12542  -33.932771  66.293738    7007

# %%
Query='''
DELETE FROM users2020
WHERE name = 'Alfred Schmidt';
'''

engine.execute(Query)

DF5=pd.read_sql("SELECT * FROM users2020" , engine);
DF5.tail(10)
